# %% [markdown]
# <a href="https://colab.research.google.com/github/srujith2006/QuantumCircuitsWithIBMcomposure/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit-ibm-runtime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.8/386.8 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

QiskitRuntimeService.save_account(
token="2z1Hqp6fOqtnMxy0lqhvw-o9eWQ8KiLnS4RqK9UGs7oY", # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard
instance="crn:v1:bluemix:public:quantum-computing:us-east:a/ccdeeb8aa71347fcbf674635b419dbdc:18bc4e97-4ee8-4b33-b41b-d6a3a8334f29::", # Optional
)
# Out:
# /usr/local/lib/python3.12/dist-packages/samplomatic/__init__.py:20: UserWarning:
# You have imported samplomatic==0.18.0 which is in
# beta development. Please expect breaking changes between
# minor versions and pin your dependencies accordingly.
#   _warn_once_per_version(

# %%
from qiskit import QuantumCircuit

# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[1];
creg c[4];

id q[0];
"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌───┐
#   q: ┤ I ├
#      └───┘
# c: 4/═════

# %%
from qiskit import QuantumCircuit

# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[1];
creg c[4];
x q[0];
"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌───┐
#   q: ┤ X ├
#      └───┘
# c: 4/═════

# %%
# Install Qiskit
# !pip install qiskit qiskit-aer -q

from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector
from qiskit.visualization import (
    plot_bloch_multivector,
    plot_histogram
)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 39.0 MB/s eta 0:00:00

# %%
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt

# %%
from qiskit import QuantumCircuit

# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[1];
creg c[4];
measure q[0] -> c[0];
y q[0];
"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌─┐┌───┐
#   q: ┤M├┤ Y ├
#      └╥┘└───┘
# c: 4/═╩══════
#       0

# %%
from qiskit import QuantumCircuit

# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[1];
creg c[4];
y q[0];
measure q[0] -> c[0];
"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌───┐┌─┐
#   q: ┤ Y ├┤M├
#      └───┘└╥┘
# c: 4/══════╩═
#            0

# %%
# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[2];
creg c[4];
h q[0];
z q[0];
h q[0];
measure q[0] -> c[0];

"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌───┐┌───┐┌───┐┌─┐
# q_0: ┤ H ├┤ Z ├┤ H ├┤M├
#      └───┘└───┘└───┘└╥┘
# q_1: ────────────────╫─
#                      ║
# c: 4/════════════════╩═
#                      0

# %%
# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[2];
creg c[4];
measure q[0] -> c[0];
h q[0];
s q[0];

"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌─┐┌───┐┌───┐
# q_0: ┤M├┤ H ├┤ S ├
#      └╥┘└───┘└───┘
# q_1: ─╫───────────
#       ║
# c: 4/═╩═══════════
#       0

# %%
# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[1];
creg c[4];
reset q[0];
h q[0];
t q[0];


"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#           ┌───┐┌───┐
#   q: ─|0>─┤ H ├┤ T ├
#           └───┘└───┘
# c: 4/═══════════════

# %%
# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[3];
creg c[4];
h q[0];
cx q[0], q[1];
cx q[1], q[2];


"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌───┐
# q_0: ┤ H ├──■───────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■──
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├
#                └───┘
# c: 4/═══════════════

# %%
# OpenQASM code
qasm_code = """
OPENQASM 2.0;
include "qelib1.inc";

qreg q[2];
creg c[4];
u(pi/4, pi/2, pi/2) q[0];


"""

# Parse QASM into Qiskit circuit
qc = QuantumCircuit.from_qasm_str(qasm_code)

# Draw the circuit
print(qc.draw())
# Out:
#      ┌────────────────┐
# q_0: ┤ U(π/4,π/2,π/2) ├
#      └────────────────┘
# q_1: ──────────────────
#
# c: 4/══════════════════
